# %%
# !pip install ultralytics

# %%
import os

for root, dirs, files in os.walk("/kaggle/input/traffic-sign-gtrb"):
    print(root)
    break

# %%
# !ls /kaggle/input/traffic-sign-gtrb

# %%
pip install ultralytics opencv-python matplotlib

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("doganozcan/traffic-sign-gtrb")

print("Path to dataset files:", path)

# %%
import yaml

data = {
    'path': '/kaggle/input/traffic-sign-gtrb',  # dataset root
    'train': '/kaggle/input/traffic-sign-gtrb/train/images',
    'val': '/kaggle/input/traffic-sign-gtrb/test/images',
    'nc': 43,
    'names': [
    '20_speed',
    '30_speed',
    '50_speed',
    '60_speed',
    '70_speed',
    '80_speed',
    '80_lifted',
    '100_speed',
    '120_speed',
    'no_overtaking_general',
    'no_overtaking_trucks',
    'right_of_way_crossing',
    'right_of_way_general',
    'give_way',
    'stop',
    'no_way_general',
    'no_way_trucks',
    'no_way_one_way',
    'attention_general',
    'attention_left_turn',
    'attention_right_turn',
    'attention_curvy',
    'attention_bumpers',
    'attention_slippery',
    'attention_bottleneck',
    'attention_construction',
    'attention_traffic_light',
    'attention_pedestrian',
    'attention_children',
    'attention_bikes',
    'attention_snowflake',
    'attention_deer',
    'lifted_general',
    'turn_right',
    'turn_left',
    'turn_straight',
    'turn_straight_right',
    'turn_straight_left',
    'turn_right_down',
    'turn_left_down',
    'turn_circle',
    'lifted_no_overtaking_general',
    'lifted_no_overtaking_trucks']
}

with open('data.yaml', 'w') as f:
    yaml.dump(data, f)

print("data.yaml created!")

# %%
from ultralytics import YOLO

def train_yolo():
    # Load YOLOv8 pretrained model
    model = YOLO("yolov8n.pt")

    # Train the model
    model.train(
        data="/kaggle/working/data.yaml",
        epochs=50,
        imgsz=640,
        batch=16,
        workers=4,
        project="traffic_sign_detection",
        name="yolov8_traffic_signs",
        exist_ok=True
    )

if __name__ == "__main__":
    train_yolo()

# %%
from ultralytics import YOLO

def evaluate_model():
    model = YOLO("traffic_sign_detection/yolov8_traffic_signs/weights/best.pt")
    
    metrics = model.val()
    
    print("Evaluation Results:")
    print(metrics)

if __name__ == "__main__":
    evaluate_model()

# %%
# from ultralytics import YOLO
# import cv2

# def predict_image(image_path):
#     model = YOLO("C:\\private\\AI\\assingment\\arch tech\\Traffic Signs Recognition\\best.pt")

#     results = model(image_path, conf=0.5)

#     # Show result
#     annotated_image = results[0].plot()
#     cv2.imshow("Traffic Sign Detection", annotated_image)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()

# if __name__ == "__main__":
#     predict_image("test.jpg")

from ultralytics import YOLO
import cv2

model = YOLO("C:\\private\\AI\\assingment\\arch tech\\Traffic Signs Recognition\\best.pt")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame, conf=0.4)

    annotated_frame = results[0].plot()

    cv2.imshow("Traffic Sign Detection", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 533.2ms
# Speed: 32.2ms preprocess, 533.2ms inference, 12.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 362.2ms
# Speed: 7.8ms preprocess, 362.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 307.1ms
# Speed: 10.0ms preprocess, 307.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 305.2ms
# Speed: 3.8ms preprocess, 305.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 309.4ms
# Speed: 3.9ms preprocess, 309.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 301.7ms
# Speed: 3.7ms preprocess, 301.7ms inference, 25.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 312.6ms
# Speed: 4.1ms preprocess, 312.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 269.1ms
# Speed: 4.6ms preprocess, 269.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 325.6ms
# Speed: 3.0ms preprocess, 325.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 244.0ms
# Speed: 3.6ms preprocess, 244.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 244.9ms
# Speed: 3.7ms preprocess, 244.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 234.4ms
# Speed: 2.2ms preprocess, 234.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 214.8ms
# Speed: 2.6ms preprocess, 214.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 246.3ms
# Speed: 2.2ms preprocess, 246.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 225.3ms
# Speed: 2.7ms preprocess, 225.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.2ms
# Speed: 2.6ms preprocess, 207.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 218.7ms
# Speed: 2.2ms preprocess, 218.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 234.6ms
# Speed: 2.8ms preprocess, 234.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 204.2ms
# Speed: 2.2ms preprocess, 204.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 245.0ms
# Speed: 4.4ms preprocess, 245.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 243.5ms
# Speed: 1.6ms preprocess, 243.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 248.8ms
# Speed: 1.6ms preprocess, 248.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 248.4ms
# Speed: 2.9ms preprocess, 248.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 251.3ms
# Speed: 2.4ms preprocess, 251.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 234.1ms
# Speed: 3.0ms preprocess, 234.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 247.4ms
# Speed: 3.5ms preprocess, 247.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 226.6ms
# Speed: 3.9ms preprocess, 226.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 without_mask, 206.8ms
# Speed: 2.5ms preprocess, 206.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 210.7ms
# Speed: 2.7ms preprocess, 210.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 238.5ms
# Speed: 3.3ms preprocess, 238.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 194.8ms
# Speed: 1.7ms preprocess, 194.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 187.1ms
# Speed: 2.3ms preprocess, 187.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 196.0ms
# Speed: 2.5ms preprocess, 196.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
